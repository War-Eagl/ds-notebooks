# %% [markdown]
# <a href="https://colab.research.google.com/github/War-Eagl/ds-notebooks/blob/master/FaceDetector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastai.vision import *

# %%
classes=['trump','dhoni','RDJ']

# %%
download_images('/content/data/msd/msd.txt', '/content/data/msd', max_pics=200)
# Out:
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# ...

# %%
download_images('/content/data/rdj/rdj.txt', '/content/data/rdj', max_pics=200)
# Out:
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# ...

# %%
download_images('/content/data/trump/donald trump.txt', '/content/data/trump', max_pics=200)
# Out:
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# ...

# %%
path='/content/data'
classes=['msd','rdj','trump']

# %%
verify_images('/content/data/msd', delete=True, max_size=500)
verify_images('/content/data/rdj', delete=True, max_size=500)
verify_images('/content/data/trump', delete=True, max_size=500)

# %%
np.random.seed(42)
data=ImageDataBunch.from_folder('/content/data',train='.',valid_pct=0.2,ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['msd', 'rdj', 'trump']

# %%
data.show_batch(rows=3,figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['msd', 'rdj', 'trump'], 3, 384, 96)

# %%
learn=cnn_learner(data,models.resnet34,metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.474891</td>
#       <td>0.819421</td>
#       <td>0.281250</td>
#       <td>02:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.871672</td>
#       <td>0.322042</td>
#       <td>0.083333</td>
#       <td>02:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.606646</td>
#       <td>0.208475</td>
#       <td>0.062500</td>
#       <td>02:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.469897</td>
#       <td>0.181263</td>
#       <td>0.062500</td>
#       <td>02:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze
# Out:
# <bound method Learner.unfreeze of Learner(data=ImageDataBunch;
#
# Train: LabelList (384 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# rdj,rdj,rdj,rdj,rdj
# Path: /content/data;
#
# Valid: LabelList (96 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# rdj,trump,trump,msd,trump
# Path: /content/data;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='13' class='' max='17', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       76.47% [13/17 26:19<08:06]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-3,3e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.131035</td>
#       <td>0.147802</td>
#       <td>0.041667</td>
#       <td>02:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.192468</td>
#       <td>0.249940</td>
#       <td>0.041667</td>
#       <td>02:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
learn.export()

# %%
# ?learn.export()

# %%
import shutil

# %%
shutil.copyfile('/content/data/export.pkl','/content/drive/My Drive')
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-33-e6e611a870eb> in <module>()
# ----> 1 shutil.copyfile('/content/data/export.pkl','/content/drive/My Drive')
#
# /usr/lib/python3.6/shutil.py in copyfile(src, dst, follow_symlinks)
#     119     else:
#     120         with open(src, 'rb') as fsrc:
# --> 121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#     123     return dst
#
# IsADirectoryError: [Errno 21] Is a directory: '/content/drive/My Drive'

# %%
learn.path=Path('/content/drive/My Drive')

# %%
learn.export()
